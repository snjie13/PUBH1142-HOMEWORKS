# %% [markdown]
# ## Quiz Questions

# %% [markdown]
# 1. To protect individual privacy by preventing identification while allowing data to be used for research or analysis.

# %% [markdown]
# 2. Researchers used tribal blood samples for purposes beyond the original consent, violating informed consent and cultural rights.

# %% [markdown]
# 3. The 2015 Anthem breach affecting 78.8 million individuals.

# %% [markdown]
# 4. The device was less accurate in detecting low oxygen levels in Black patients due to biased algorithm development.

# %% [markdown]
# 5. To review and monitor research involving human subjects to ensure ethical standards and participant protection.

# %% [markdown]
# 6. Spreadsheets store data in simple tables for smaller datasets; databases manage large, complex datasets with better security, relationships, and querying functions.

# %% [markdown]
# 7. A situation where secondary interests (financial, personal, academic) may bias professional judgment.

# %% [markdown]
# 8. Providing individuals with sufficient information about data collection and use so they can voluntarily decide whether to participate.

# %% [markdown]
# 9. Replacing or removing identifiable information to protect privacy.

# %% [markdown]
# 10. Ensuring each individual’s data cannot be distinguished from at least k-1 other individuals in the dataset.

# %% [markdown]
# 11. They can bias research findings and undermine public trust.

# %% [markdown]
# 12. Transparency and disclosure.

# %% [markdown]
# 13. To review research and ensure conflicts do not compromise integrity.

# %% [markdown]
# 14. Divestment or public disclosure.

# %% [markdown]
# 15. Biased research, loss of credibility, policy decisions based on flawed evidence, and erosion of public trust.
