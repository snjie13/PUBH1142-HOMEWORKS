# %% [markdown]
# ## Quiz Questions

# %% [markdown]
# ### Question one

# %% [markdown]
#  To protect individual privacy by preventing identification while allowing data to be used for research or analysis.

# %% [markdown]
# ### Question two

# %% [markdown]
#  Researchers used tribal blood samples for purposes beyond the original consent, violating informed consent and cultural rights.

# %% [markdown]
# ### Question three

# %% [markdown]
# The 2015 Anthem breach affecting 78.8 million individuals.

# %% [markdown]
# ### Question four

# %% [markdown]
#  The device was less accurate in detecting low oxygen levels in Black patients due to biased algorithm development.

# %% [markdown]
# ### Question five

# %% [markdown]
#  To review and monitor research involving human subjects to ensure ethical standards and participant protection.

# %% [markdown]
# ### Question Six

# %% [markdown]
#  Spreadsheets store data in simple tables for smaller datasets; databases manage large, complex datasets with better security, relationships, and querying functions.

# %% [markdown]
# ### Question Seven

# %% [markdown]
#  A situation where secondary interests (financial, personal, academic) may bias professional judgment.

# %% [markdown]
# ### Question Eight

# %% [markdown]
#  Providing individuals with sufficient information about data collection and use so they can voluntarily decide whether to participate.

# %% [markdown]
# ### Question Nine

# %% [markdown]
#  Replacing or removing identifiable information to protect privacy.

# %% [markdown]
# ### Question Ten

# %% [markdown]
#  Ensuring each individual’s data cannot be distinguished from at least k-1 other individuals in the dataset.

# %% [markdown]
# ### Question Eleven

# %% [markdown]
#  They can bias research findings and undermine public trust.

# %% [markdown]
# ### Question Twelve

# %% [markdown]
#  Transparency and disclosure.

# %% [markdown]
# ### Question Thirteen

# %% [markdown]
#  To review research and ensure conflicts do not compromise integrity.

# %% [markdown]
# ### Question Fourteen

# %% [markdown]
#  Divestment or public disclosure.

# %% [markdown]
# ### Question Fifteen

# %% [markdown]
#  Biased research, loss of credibility, policy decisions based on flawed evidence, and erosion of public trust.
